# %%
# Define a function calls addNumber(x, y) that takes in two number and returns the sum of the two numbers.

def func(x,y):
    z=x+y
    return z
print(func(3,5))
# Out:
# 8

# %%
# Define a function calls subtractNumber(x, y) that takes in two numbers and returns the difference of the two numbers.
def func(x,y):
    z=x-y
    return z
print(func(3,5))
# Out:
# -2

# %%
# Write a function getBiggerNumber(x, y) that takes in two numbers as arguments and returns the bigger number.
def func(x,y):
    if x > y:
        z=x
    else:
        z=y
    return z
print(func(9,5))
# Out:
# 9

# %%
# Python provides many built-in modules with many useful functions. 
# One such module is the math module. The math module provides many useful functions such as sqrt(x), pow(x, y), ceil(x), floor(x) etc. 
# You will need to do a "import math" before you are allowed to use the functions within the math module.

import math
# Calculate the square root of 16 and stores it in the variable a
a=math.sqrt(16)
print(a)

# Calculate 3 to the power of 5 and stores it in the variable b
b=3**5
print(b)

# Calculate area of circle with radius = 3.0 by making use of the math.pi constant and store it in the variable c
r=20
res=math.pi*r*r
print(res)
# Out:
# 4.0
# 243
# 1256.6370614359173

# %%
# Write a function to convert temperature from Celsius to Fahrenheit scale.
# oC to oF Conversion: Multipy by 9, then divide by 5, then add 32.

# Note: Return a string of 2 decimal places.
# In - Cel2Fah(28.0)
# Out - '82.40'
# In - Cel2Fah(0.00)
# Out - '32.00'

def func(c):
    f=((c*9)/5)+32
    return f

a=func(0.0)
b=func(28.0)
print ('%.2f'%b)
print ('%.2f'%a)
# Out:
# 82.40
# 32.00

# %%
# Write a function to compute the BMI of a person.
#     BMI = weight(kg)  /  ( height(m)*height(m) )

# Note: Return a string of 1 decimal place.
# In - BMI(63, 1.7)
# Out - '21.8'
# In - BMI(110, 2)
# Out - '27.5'

def bmi_func(w,h):
    bmi=(w/(h*h))
    return bmi
a=bmi_func(63, 1.7)
b=bmi_func(110, 2) 
print(round(a,2),round(b,3))
# Out:
# 21.8 27.5

# %%
# Write a function percent(value, total) that takes in two numbers as arguments, and returns the percentage value as an integer.
# In - percent(46, 90)
# Out - 51
# In - percent(51, 51)
# Out - 100
# In - percent(63, 12)
# Out - 525

def percent(value, total):
    res=(value/total)*100
    return res

print('%.0f'%percent(46, 90))  
print('%.0f'%percent(63, 12))
# Out:
# 51
# 525

# %%
# Write a function to compute the hypotenuse given sides a and b of the triangle.
# Hint: You can use math.sqrt(x) to compute the square root of x.
# In - hypotenuse(3, 4)
# Out - 5
# In - hypotenuse(5, 12)
# Out - 13

def hypotenuse(a,b):
    h=math.sqrt(a*a+b*b)
    return h

print('%.0f'%hypotenuse(3, 4))
print('%.0f'%hypotenuse(5,12))
# Out:
# 5
# 13

# %%
# Write a function getSumOfLastDigits() that takes in a list of positive numbers and returns the sum of all the last digits in the list.
# getSumOfLastDigits([2, 3, 4])
# 9
# getSumOfLastDigits([1, 23, 456])
# 10

def func(li):
    for i in li:
        z=sum(li)
    return z
print(func([2, 3, 4]))
print(func([1, 23, 456]))  

# using reduce
#reduce(lambda x,y:x+y,[2, 3, 4])
# Out:
# 9
# 480

# %%
# Write a function that uses a default value.
# In - introduce('Lim', 20)
# Out - 'My name is Lim. I am 20 years old.'
# In - introduce('Ahmad')
# Out - 'My name is Ahmad. My age is secret.'

def func(name,age='secret'):
    #name=input("Eneter your name: ")
    if str(age).lower()=='secret':
        out="My name is {0}. My age is {1}".format(name,age)
    else:
        out="My name is {0}. I am {1} years old.".format(name,age)
    return out

print(func('Lim', 20))
print(func('Ahmad'))
# Out:
# My name is Lim. I am 20 years old.
# My name is Ahmad. My age is secret

# %%
# Write a function isEquilateral(x, y, z) that accepts the 3 sides of a triangle as arguments. 
# The program should return True if it is an equilateral triangle.

# In - isEquilateral(2, 4, 3)
# False - False
# In - isEquilateral(3, 3, 3)
# Out - True
# In - isEquilateral(-3, -3, -3)
# Out - False

def isEquilateral(a,b,c):
    if a==b==c:
        return True
    else:
        return False
print(func(2, 4, 3))
print(func(3, 3, 3))
print(func(-3, -3, -3))
#**The last one is coming as Ture**
# Out:
# False
# True
# True

# %%
# For a quadratic equation in the form of ax2+bx+c, the discriminant, D is b^2-4ac. Write a function to compute the discriminant, D.
# In - quadratic(1, 2, 3)
# Out - 'The discriminant is -8.'
# In - quadratic(1, 3, 2)
# Out - 'The discriminant is 1.'
# In - quadratic(1, 4, 4)
# Out - 'The discriminant is 0.'
def func(a,b,c):
    discriminant=((b*b)-(4*a*c))
    return discriminant
print(func(1, 2, 3))
print(func(1, 3, 2))
print(func(1, 4, 4))
# Out:
# -8
# 1
# 0

# %%
# Define a function calls addFirstAndLast(x) that takes in a list of numbers and returns the sum of the first and last numbers.
# In - addFirstAndLast([])
# Out - 0
# In - addFirstAndLast([2, 7, 3])
# Out - 5
# In - addFirstAndLast([10])
# Out - 10

def addFirstAndLast(lst):
    if len(lst) == 1:
        return lst[0]
    elif lst:
        return lst[0] + lst[-1]
    else:
        return 'List is empty'

print(addFirstAndLast([2,7,3]))
print(addFirstAndLast([10]))
# Out:
# 5
# 10

# %%
# Complete the 'lambda' expression so that it returns True if the argument is an even number, and False otherwise.

(lambda num : True if num%2 == 0 else False)(6)
# Out:
# True

# %%
# getScore.__doc__
# 'A function that computes and returns the final score.'

def getScore():
    ''''A function that computes and returns the final score.'''
    pass
getScore.__doc__
# Out:
# "'A function that computes and returns the final score."

# %%
# In Python, it is possible to pass a function as a argument to another function. 
# Write a function useFunction(func, num) that takes in a function and a number as arguments. 
# The useFunction should produce the output shown in the examples given below.

# def addOne(x):
#   return x + 1
# useFunction(addOne, 4)
# 25
# useFunction(addOne, 9)
# 100
# useFunction(addOne, 0)
# 1


def addOne(x):
    return x + 1

def useFunction(addOne, n):
    print(addOne(n)**2)

useFunction(addOne, 4)
# Out:
# 25

# %%
def f1():
    print('This is f1 function')
    f1()
f1()

#You are keep on calling the function
# Out:
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# ...

# %%
print('\\t')
# Out:
# \t
